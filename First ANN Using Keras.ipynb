# %%
import keras
from keras.models import Sequential 
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout
import pandas as pd

# %%
keras.__version__
# Out:
# '2.5.0'

# %%
ls
# Out:
# Churn_Modelling.csv  file.txt  Untitled.ipynb

# %%
df = pd.read_csv("Churn_Modelling.csv")

x = df.iloc[:,3:13]
y = df.iloc[:,13]

x
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
# Create a Dummy in case of geography
geography=pd.get_dummies(x["Geography"],drop_first=True)
gender=pd.get_dummies(x['Gender'],drop_first=True)

# %%
# Concating back to df

x=pd.concat([x,geography,gender],axis=1)

## Drop Unnecessary columns
x=x.drop(columns = ['Geography','Gender'],axis=1)

# %%
x
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0                  1        101348.88        0      0     0
# 1                  1        112542.58        0      1     0
# 2                  0        113931.57        0      0     0
# 3                  0         93826.63        0      0     0
# 4                  1         79084.10        0      1     0
# ...              ...              ...      ...    ...   ...
# 9995               0         96270.64        0      0     1
# 9996               1        101699.77        0      0     1
# 9997               1         42085.58        0      0     0
# 9998               0         92888.52        1      0     1
# 9999               0         38190.78        0      0     0
#
# [10000 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Initialising the ANN
classifier = Sequential()

# %%
# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform',activation='relu',input_dim = 11))

# %%
classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform',activation='relu'))

# %%
# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# %%
# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 6)                 72
# _________________________________________________________________
# dense_5 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting the ANN to the Training set
model_history=classifier.fit(X_train, y_train,validation_split=0.33, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 20s 4ms/step - loss: 0.6171 - accuracy: 0.6484 - val_loss: 0.5134 - val_accuracy: 0.7974
# Epoch 2/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4827 - accuracy: 0.8013 - val_loss: 0.4762 - val_accuracy: 0.7978
# Epoch 3/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4454 - accuracy: 0.8097 - val_loss: 0.4594 - val_accuracy: 0.7982
# Epoch 4/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4289 - accuracy: 0.8154 - val_loss: 0.4501 - val_accuracy: 0.8061
# Epoch 5/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4308 - accuracy: 0.8160 - val_loss: 0.4437 - val_accuracy: 0.8042
# Epoch 6/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4386 - accuracy: 0.8075 - val_loss: 0.4372 - val_accuracy: 0.8107
# Epoch 7/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4292 - accuracy: 0.8106 - val_loss: 0.4321 - val_accuracy: 0.8118
# Epoch 8/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4144 - accuracy: 0.8197 - val_loss: 0.4269 - val_accuracy: 0.8156
# Epoch 9/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4219 - accuracy: 0.8166 - val_loss: 0.4205 - val_accuracy: 0.8186
# Epoch 10/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4024 - accuracy: 0.8283 - val_loss: 0.4125 - val_accuracy: 0.8220
# Epoch 11/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3972 - accuracy: 0.8338 - val_loss: 0.4035 - val_accuracy: 0.8277
# Epoch 12/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3956 - accuracy: 0.8355 - val_loss: 0.3941 - val_accuracy: 0.8315
# Epoch 13/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3679 - accuracy: 0.8454 - val_loss: 0.3855 - val_accuracy: 0.8391
# Epoch 14/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3727 - accuracy: 0.8420 - val_loss: 0.3783 - val_accuracy: 0.8436
# Epoch 15/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3547 - accuracy: 0.8578 - val_loss: 0.3694 - val_accuracy: 0.8485
# Epoch 16/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3565 - accuracy: 0.8533 - val_loss: 0.3682 - val_accuracy: 0.8508
# Epoch 17/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3558 - accuracy: 0.8531 - val_loss: 0.3606 - val_accuracy: 0.8554
# Epoch 18/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3544 - accuracy: 0.8557 - val_loss: 0.3596 - val_accuracy: 0.8550
# Epoch 19/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3522 - accuracy: 0.8543 - val_loss: 0.3573 - val_accuracy: 0.8538
# Epoch 20/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3433 - accuracy: 0.8638 - val_loss: 0.3557 - val_accuracy: 0.8569
# Epoch 21/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3424 - accuracy: 0.8646 - val_loss: 0.3544 - val_accuracy: 0.8591
# Epoch 22/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3398 - accuracy: 0.8677 - val_loss: 0.3536 - val_accuracy: 0.8550
# Epoch 23/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3440 - accuracy: 0.8623 - val_loss: 0.3535 - val_accuracy: 0.8519
# Epoch 24/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3512 - accuracy: 0.8518 - val_loss: 0.3527 - val_accuracy: 0.8580
# Epoch 25/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3556 - accuracy: 0.8516 - val_loss: 0.3513 - val_accuracy: 0.8599
# Epoch 26/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3535 - accuracy: 0.8570 - val_loss: 0.3524 - val_accuracy: 0.8546
# Epoch 27/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3476 - accuracy: 0.8592 - val_loss: 0.3497 - val_accuracy: 0.8573
# Epoch 28/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3505 - accuracy: 0.8568 - val_loss: 0.3492 - val_accuracy: 0.8595
# Epoch 29/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3311 - accuracy: 0.8631 - val_loss: 0.3540 - val_accuracy: 0.8512
# Epoch 30/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3418 - accuracy: 0.8577 - val_loss: 0.3475 - val_accuracy: 0.8618
# Epoch 31/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3377 - accuracy: 0.8720 - val_loss: 0.3495 - val_accuracy: 0.8561
# Epoch 32/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3415 - accuracy: 0.8575 - val_loss: 0.3476 - val_accuracy: 0.8595
# Epoch 33/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3354 - accuracy: 0.8648 - val_loss: 0.3483 - val_accuracy: 0.8561
# Epoch 34/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3466 - accuracy: 0.8577 - val_loss: 0.3465 - val_accuracy: 0.8610
# Epoch 35/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3567 - accuracy: 0.8514 - val_loss: 0.3462 - val_accuracy: 0.8633
# Epoch 36/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3282 - accuracy: 0.8683 - val_loss: 0.3552 - val_accuracy: 0.8542
# Epoch 37/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3499 - accuracy: 0.8614 - val_loss: 0.3446 - val_accuracy: 0.8614
# Epoch 38/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3428 - accuracy: 0.8622 - val_loss: 0.3448 - val_accuracy: 0.8648
# Epoch 39/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3357 - accuracy: 0.8587 - val_loss: 0.3454 - val_accuracy: 0.8595
# Epoch 40/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3384 - accuracy: 0.8627 - val_loss: 0.3440 - val_accuracy: 0.8622
# Epoch 41/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3328 - accuracy: 0.8613 - val_loss: 0.3433 - val_accuracy: 0.8614
# Epoch 42/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3590 - accuracy: 0.8541 - val_loss: 0.3435 - val_accuracy: 0.8629
# Epoch 43/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3282 - accuracy: 0.8667 - val_loss: 0.3432 - val_accuracy: 0.8614
# Epoch 44/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3464 - accuracy: 0.8614 - val_loss: 0.3427 - val_accuracy: 0.8637
# Epoch 45/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3335 - accuracy: 0.8642 - val_loss: 0.3438 - val_accuracy: 0.8618
# Epoch 46/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3305 - accuracy: 0.8630 - val_loss: 0.3422 - val_accuracy: 0.8629
# Epoch 47/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3317 - accuracy: 0.8622 - val_loss: 0.3436 - val_accuracy: 0.8626
# Epoch 48/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3417 - accuracy: 0.8631 - val_loss: 0.3435 - val_accuracy: 0.8618
# Epoch 49/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3277 - accuracy: 0.8657 - val_loss: 0.3430 - val_accuracy: 0.8626
# Epoch 50/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3401 - accuracy: 0.8595 - val_loss: 0.3451 - val_accuracy: 0.8614
# Epoch 51/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3263 - accuracy: 0.8675 - val_loss: 0.3429 - val_accuracy: 0.8618
# Epoch 52/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3301 - accuracy: 0.8635 - val_loss: 0.3405 - val_accuracy: 0.8618
# Epoch 53/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3341 - accuracy: 0.8634 - val_loss: 0.3427 - val_accuracy: 0.8644
# Epoch 54/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3402 - accuracy: 0.8593 - val_loss: 0.3434 - val_accuracy: 0.8607
# Epoch 55/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3265 - accuracy: 0.8681 - val_loss: 0.3410 - val_accuracy: 0.8633
# Epoch 56/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3413 - accuracy: 0.8545 - val_loss: 0.3445 - val_accuracy: 0.8652
# Epoch 57/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3179 - accuracy: 0.8710 - val_loss: 0.3422 - val_accuracy: 0.8667
# Epoch 58/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3406 - accuracy: 0.8572 - val_loss: 0.3412 - val_accuracy: 0.8633
# Epoch 59/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3259 - accuracy: 0.8657 - val_loss: 0.3417 - val_accuracy: 0.8641
# Epoch 60/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3237 - accuracy: 0.8690 - val_loss: 0.3401 - val_accuracy: 0.8644
# Epoch 61/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3170 - accuracy: 0.8716 - val_loss: 0.3448 - val_accuracy: 0.8633
# Epoch 62/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3150 - accuracy: 0.8715 - val_loss: 0.3401 - val_accuracy: 0.8618
# Epoch 63/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3291 - accuracy: 0.8625 - val_loss: 0.3416 - val_accuracy: 0.8629
# Epoch 64/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3345 - accuracy: 0.8617 - val_loss: 0.3443 - val_accuracy: 0.8622
# Epoch 65/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3268 - accuracy: 0.8628 - val_loss: 0.3399 - val_accuracy: 0.8648
# Epoch 66/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3304 - accuracy: 0.8676 - val_loss: 0.3429 - val_accuracy: 0.8614
# Epoch 67/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3160 - accuracy: 0.8723 - val_loss: 0.3395 - val_accuracy: 0.8644
# Epoch 68/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3382 - accuracy: 0.8596 - val_loss: 0.3396 - val_accuracy: 0.8637
# Epoch 69/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3307 - accuracy: 0.8638 - val_loss: 0.3403 - val_accuracy: 0.8629
# Epoch 70/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3280 - accuracy: 0.8694 - val_loss: 0.3445 - val_accuracy: 0.8633
# Epoch 71/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3292 - accuracy: 0.8644 - val_loss: 0.3416 - val_accuracy: 0.8633
# Epoch 72/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3358 - accuracy: 0.8657 - val_loss: 0.3406 - val_accuracy: 0.8637
# Epoch 73/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3346 - accuracy: 0.8652 - val_loss: 0.3422 - val_accuracy: 0.8633
# Epoch 74/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3390 - accuracy: 0.8576 - val_loss: 0.3409 - val_accuracy: 0.8660
# Epoch 75/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3249 - accuracy: 0.8726 - val_loss: 0.3405 - val_accuracy: 0.8652
# Epoch 76/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3250 - accuracy: 0.8750 - val_loss: 0.3429 - val_accuracy: 0.8633
# Epoch 77/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3462 - accuracy: 0.8588 - val_loss: 0.3412 - val_accuracy: 0.8667
# Epoch 78/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3275 - accuracy: 0.8683 - val_loss: 0.3408 - val_accuracy: 0.8637
# Epoch 79/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3435 - accuracy: 0.8608 - val_loss: 0.3385 - val_accuracy: 0.8648
# Epoch 80/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3325 - accuracy: 0.8696 - val_loss: 0.3391 - val_accuracy: 0.8622
# Epoch 81/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3348 - accuracy: 0.8663 - val_loss: 0.3406 - val_accuracy: 0.8660
# Epoch 82/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3344 - accuracy: 0.8616 - val_loss: 0.3425 - val_accuracy: 0.8641
# Epoch 83/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3353 - accuracy: 0.8597 - val_loss: 0.3403 - val_accuracy: 0.8671
# Epoch 84/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3366 - accuracy: 0.8612 - val_loss: 0.3389 - val_accuracy: 0.8660
# Epoch 85/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3438 - accuracy: 0.8527 - val_loss: 0.3407 - val_accuracy: 0.8667
# Epoch 86/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3269 - accuracy: 0.8660 - val_loss: 0.3406 - val_accuracy: 0.8656
# Epoch 87/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3160 - accuracy: 0.8755 - val_loss: 0.3395 - val_accuracy: 0.8667
# Epoch 88/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3226 - accuracy: 0.8688 - val_loss: 0.3393 - val_accuracy: 0.8660
# Epoch 89/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3255 - accuracy: 0.8739 - val_loss: 0.3400 - val_accuracy: 0.8652
# Epoch 90/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3373 - accuracy: 0.8656 - val_loss: 0.3410 - val_accuracy: 0.8652
# Epoch 91/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3362 - accuracy: 0.8590 - val_loss: 0.3408 - val_accuracy: 0.8656
# Epoch 92/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3405 - accuracy: 0.8588 - val_loss: 0.3388 - val_accuracy: 0.8648
# Epoch 93/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3236 - accuracy: 0.8665 - val_loss: 0.3402 - val_accuracy: 0.8671
# Epoch 94/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3284 - accuracy: 0.8595 - val_loss: 0.3421 - val_accuracy: 0.8641
# Epoch 95/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3292 - accuracy: 0.8597 - val_loss: 0.3422 - val_accuracy: 0.8686
# Epoch 96/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3281 - accuracy: 0.8698 - val_loss: 0.3391 - val_accuracy: 0.8641
# Epoch 97/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3215 - accuracy: 0.8701 - val_loss: 0.3422 - val_accuracy: 0.8686
# Epoch 98/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3276 - accuracy: 0.8672 - val_loss: 0.3425 - val_accuracy: 0.8637
# Epoch 99/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3241 - accuracy: 0.8704 - val_loss: 0.3381 - val_accuracy: 0.8652
# Epoch 100/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3251 - accuracy: 0.8670 - val_loss: 0.3385 - val_accuracy: 0.8667

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1503,   73],
#        [ 235,  189]])

# %%
# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)

score
# Out:
# 0.846
